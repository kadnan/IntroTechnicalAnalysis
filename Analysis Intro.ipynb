# %%
# All Imports
import yfinance as yf
import talib as ta
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Facebook Historial Data
fb = yf.Ticker("FB")
df = fb.history(start="2022-01-03")

# %%
plt.style.use('fivethirtyeight')
df['MA'] = ta.SMA(df['Close'],timeperiod=5)
df['EMA'] = ta.EMA(df['Close'], timeperiod = 5)
df[['Close','MA','EMA']].plot(figsize=(8,8))
plt.show()

# %%
# RSI
df['RSI'] = ta.RSI(df['Close'],14)
df['RSI'].plot(figsize=(8,8),marker='o')
df.tail(10)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2022-01-27  297.750000  301.709991  294.260010  294.640015   21629900
# 2022-01-28  295.619995  301.899994  293.029999  301.709991   21871600
# 2022-01-31  300.679993  313.790009  299.320007  313.260010   21579500
# 2022-02-01  314.559998  319.660004  312.119995  319.000000   18023800
# 2022-02-02  327.820007  328.000000  316.869995  323.000000   58458300
# 2022-02-03  244.649994  248.000000  235.750000  237.759995  188119900
# 2022-02-04  234.970001  242.610001  230.110001  237.089996   89203700
# 2022-02-07  237.699997  238.300003  224.009995  224.910004   88613800
# 2022-02-08  220.850006  225.770004  216.149994  220.179993   94729700
# 2022-02-09  224.199997  233.369995  222.210007  232.000000   86460400
#
#             Dividends  Stock Splits          MA         EMA        RSI
# Date
# 2022-01-27          0             0  300.260004  300.974816  27.153754
# 2022-01-28          0             0  299.967999  301.219875  33.511862
# 2022-01-31          0             0  300.878003  305.233253  42.362512
# 2022-02-01          0             0  304.648004  309.822169  46.195708
# 2022-02-02          0             0  310.322003  314.214779  48.753436
# 2022-02-03          0             0  298.945999  288.729851  23.316385
# 2022-02-04          0             0  286.022000  271.516566  23.213862
# 2022-02-07          0             0  268.351999  255.981045  21.373917
# 2022-02-08          0             0  248.587997  244.047361  20.688147
# 2022-02-09          0             0  230.387997  240.031574  26.991990
